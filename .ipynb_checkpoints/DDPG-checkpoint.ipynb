# %%
import gym
import gym_mppt
from gym import envs
all_envs = envs.registry.all()
env_ids = [env_spec.id for env_spec in all_envs]
print(sorted(env_ids)[-2:])
# Out:
# ['mppt_shaded-v0', 'mppt_shaded-v1']

# %%
env = gym.make("mppt_shaded-v1")

num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  15.0
# Min Value of Action ->  -15.0

# %%
import numpy as np
import stable_baselines3
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %%
# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1, batch_size=256)
model.learn(total_timesteps=1000000, log_interval=10, progress_bar=True)
model.save("DDPG_v1")
env = model.get_env()
# Out:
# Output()
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\users\archi\mppt-gym_v2\gym_mppt\envs\mppt_env_shaded1.py:78: RuntimeWarning: overflow encountered in exp
#   I = self.Np * Iph - self.Np * Irs * (np.exp(self.q / (self.k * Tcell * self.A) * vx * (1/SH) / self.Ns) - 1)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | -2.65e+06 |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 98        |
# |    time_elapsed    | 10        |
# |    total_timesteps | 1000      |
# | train/             |           |
# |    actor_loss      | 1.24e+05  |
# |    critic_loss     | 3.15e+09  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 800       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# ...

# %%
model = DDPG.load("shaded_test")

for i in range(10):
    obs = env.reset()
    for i in range(100):
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        print(obs)
    print()
# Out:
# [[  15.     5356.3594 5356.3594]]
# [[   30.      3355.3435 -2001.0159]]
# [[  45.     5029.9233 1674.5798]]
# [[  60.     6697.5835 1667.6602]]
# [[  75.    8347.478 1649.894]]
# [[  90.     9952.714  1605.2363]]
# [[  105.     11447.4     1494.6865]]
# [[  120.     12671.561   1224.1602]]
# [[  135.     13239.656    568.0957]]
# [[  150.      12227.838   -1011.81836]]
# [[  165.      9051.856  -3175.9814]]
# [[  180.      3317.0613 -5734.795 ]]
# [[  195.         0.     -3317.0613]]
# [[210.   0.   0.]]
# [[225.   0.   0.]]
# [[240.   0.   0.]]
# [[255.   0.   0.]]
# [[270.   0.   0.]]
# [[285.   0.   0.]]
# [[300.   0.   0.]]
# [[315.   0.   0.]]
# [[330.   0.   0.]]
# [[345.   0.   0.]]
# [[360.   0.   0.]]
# [[375.   0.   0.]]
# [[390.   0.   0.]]
# [[405.   0.   0.]]
# [[420.   0.   0.]]
# [[435.   0.   0.]]
# [[450.   0.   0.]]
# [[465.   0.   0.]]
# [[480.   0.   0.]]
# [[495.   0.   0.]]
# [[510.   0.   0.]]
# [[525.   0.   0.]]
# [[540.   0.   0.]]
# [[555.   0.   0.]]
# ...
