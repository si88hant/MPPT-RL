# %%
import gym
import gym_mppt
from gym import envs
import numpy as np
import stable_baselines3
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

import os
models_dir = "models/DDPG"
logdir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
    
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
env = gym.make("mppt_shaded-v1")

num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  15.0
# Min Value of Action ->  -15.0

# %%
import numpy as np
import stable_baselines3
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %%
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

tensorboard_log = os.path.join(logdir, "tensorboard")
model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1, batch_size=256, gamma=0.30, learning_rate=0.000001, tensorboard_log=tensorboard_log)
TIMESTEPS = 35000000
for i in range(1,30):
    model.learn(total_timesteps=TIMESTEPS, log_interval=10, progress_bar=True, reset_num_timesteps=False, tb_log_name="DDPG-successor1")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
env = model.get_env()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/tensorboard/DDPG-successor1_0
# Output()
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | -1.08e+03 |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 66        |
# |    time_elapsed    | 14        |
# |    total_timesteps | 1000      |
# | train/             |           |
# |    actor_loss      | -367      |
# |    critic_loss     | 8.43e+03  |
# |    learning_rate   | 1e-06     |
# |    n_updates       | 800       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 63        |
# ...
