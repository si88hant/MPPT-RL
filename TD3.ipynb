# %%
2, 10, 8, 10, 4,
# Out:
# ['mppt_shaded-v0', 'mppt_shaded-v1']

# %%
env = gym.make("mppt_shaded-v1")

num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  15.0
# Min Value of Action ->  -15.0

# %%
import numpy as np
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %%
# The noise objects for TD3
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = TD3("MlpPolicy", env, action_noise=action_noise, verbose=1, learning_rate=0.000001)
model.learn(total_timesteps=5000000, log_interval=10, progress_bar=True)
model.save("TD3_v1")
env = model.get_env()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 70       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 2.77e+03 |
# |    critic_loss     | 3.23e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 800      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -59.8    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 68       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 1.2e+03  |
# |    critic_loss     | 1.15e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 1800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -32.5    |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 67       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 775      |
# |    critic_loss     | 8.85e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 2800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -36.2    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 66       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 843      |
# |    critic_loss     | 7.08e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 3800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -90.1    |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 66       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 1.43e+03 |
# |    critic_loss     | 1.38e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 65       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | 1.62e+03 |
# |    critic_loss     | 1.08e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 5800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 65       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | 1.58e+03 |
# |    critic_loss     | 7.33e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 6800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 65       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 1.39e+03 |
# |    critic_loss     | 6e+05    |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 7800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -137     |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 64       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 1.41e+03 |
# |    critic_loss     | 5.87e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 8800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -168     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 64       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 1.43e+03 |
# |    critic_loss     | 1.03e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 9800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 64       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | 1.54e+03 |
# |    critic_loss     | 6.54e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 10800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -262     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 64       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 1.59e+03 |
# |    critic_loss     | 9.09e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 11800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -330     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 64       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | 1.55e+03 |
# |    critic_loss     | 1.18e+06 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 12800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -352     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 64       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 1.58e+03 |
# |    critic_loss     | 7e+05    |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 13800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -348     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 64       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 1.44e+03 |
# |    critic_loss     | 5.39e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 14800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -367     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 65       |
# |    time_elapsed    | 244      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | 1.45e+03 |
# |    critic_loss     | 5.25e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 15800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -389     |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 66       |
# |    time_elapsed    | 255      |
# |    total_timesteps | 17000    |
# | train/             |          |
# |    actor_loss      | 1.38e+03 |
# |    critic_loss     | 5.17e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 16800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -430     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 66       |
# |    time_elapsed    | 270      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | 1.4e+03  |
# |    critic_loss     | 4.47e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 17800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -439     |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 66       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 19000    |
# | train/             |          |
# |    actor_loss      | 1.39e+03 |
# |    critic_loss     | 4.44e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 18800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -426     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 66       |
# |    time_elapsed    | 299      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | 1.41e+03 |
# |    critic_loss     | 2.87e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 19800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -405     |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 66       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | 1.28e+03 |
# |    critic_loss     | 3.98e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 20800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -397     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 66       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | 1.28e+03 |
# |    critic_loss     | 3.19e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 21800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -407     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 66       |
# |    time_elapsed    | 345      |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | 1.21e+03 |
# |    critic_loss     | 3.24e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 22800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -422     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 66       |
# |    time_elapsed    | 360      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 1.18e+03 |
# |    critic_loss     | 2.61e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 23800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -461     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 66       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 1.09e+03 |
# |    critic_loss     | 3.27e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 24800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -422     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 66       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | 1.05e+03 |
# |    critic_loss     | 2.59e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 25800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -389     |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 66       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 27000    |
# | train/             |          |
# |    actor_loss      | 1e+03    |
# |    critic_loss     | 1.84e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 26800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -397     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 66       |
# |    time_elapsed    | 422      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | 953      |
# |    critic_loss     | 1.63e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 27800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -397     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 65       |
# |    time_elapsed    | 439      |
# |    total_timesteps | 29000    |
# | train/             |          |
# |    actor_loss      | 918      |
# |    critic_loss     | 1.8e+05  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 28800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -409     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 65       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | 902      |
# |    critic_loss     | 1.18e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 29800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -389     |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 65       |
# |    time_elapsed    | 471      |
# |    total_timesteps | 31000    |
# | train/             |          |
# |    actor_loss      | 894      |
# |    critic_loss     | 1.27e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 30800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -393     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 65       |
# |    time_elapsed    | 485      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | 846      |
# |    critic_loss     | 1.35e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 31800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -322     |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 65       |
# |    time_elapsed    | 500      |
# |    total_timesteps | 33000    |
# | train/             |          |
# |    actor_loss      | 805      |
# |    critic_loss     | 1.14e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 32800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -310     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 65       |
# |    time_elapsed    | 515      |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | 790      |
# |    critic_loss     | 1.09e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 33800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -275     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 65       |
# |    time_elapsed    | 530      |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | 752      |
# |    critic_loss     | 9.29e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 34800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -335     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 65       |
# |    time_elapsed    | 546      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | 711      |
# |    critic_loss     | 1.01e+05 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 35800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -394     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 65       |
# |    time_elapsed    | 560      |
# |    total_timesteps | 37000    |
# | train/             |          |
# |    actor_loss      | 703      |
# |    critic_loss     | 9.03e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 36800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -434     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 66       |
# |    time_elapsed    | 572      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | 674      |
# |    critic_loss     | 9.52e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 37800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -420     |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 66       |
# |    time_elapsed    | 586      |
# |    total_timesteps | 39000    |
# | train/             |          |
# |    actor_loss      | 668      |
# |    critic_loss     | 9.1e+04  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 38800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -412     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 66       |
# |    time_elapsed    | 601      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | 639      |
# |    critic_loss     | 7.35e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 39800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -421     |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 66       |
# |    time_elapsed    | 617      |
# |    total_timesteps | 41000    |
# | train/             |          |
# |    actor_loss      | 620      |
# |    critic_loss     | 7.64e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 40800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -428     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 66       |
# |    time_elapsed    | 632      |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | 602      |
# |    critic_loss     | 6.48e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 41800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -479     |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 66       |
# |    time_elapsed    | 647      |
# |    total_timesteps | 43000    |
# | train/             |          |
# |    actor_loss      | 607      |
# |    critic_loss     | 5.62e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 42800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -495     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 66       |
# |    time_elapsed    | 662      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | 568      |
# |    critic_loss     | 5.82e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 43800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -500     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 66       |
# |    time_elapsed    | 677      |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | 565      |
# |    critic_loss     | 5.54e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 44800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -490     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 66       |
# |    time_elapsed    | 692      |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | 539      |
# |    critic_loss     | 5.67e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 45800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -451     |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 66       |
# |    time_elapsed    | 707      |
# |    total_timesteps | 47000    |
# | train/             |          |
# |    actor_loss      | 542      |
# |    critic_loss     | 5.95e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 46800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -461     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 66       |
# |    time_elapsed    | 721      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | 506      |
# |    critic_loss     | 5.21e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 47800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -437     |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 66       |
# |    time_elapsed    | 736      |
# |    total_timesteps | 49000    |
# | train/             |          |
# |    actor_loss      | 482      |
# |    critic_loss     | 5.3e+04  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 48800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -413     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 66       |
# |    time_elapsed    | 751      |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | 460      |
# |    critic_loss     | 4.54e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 49800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -419     |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 66       |
# |    time_elapsed    | 766      |
# |    total_timesteps | 51000    |
# | train/             |          |
# |    actor_loss      | 449      |
# |    critic_loss     | 4.5e+04  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 50800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -460     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 66       |
# |    time_elapsed    | 779      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | 439      |
# |    critic_loss     | 3.88e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 51800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -442     |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 66       |
# |    time_elapsed    | 791      |
# |    total_timesteps | 53000    |
# | train/             |          |
# |    actor_loss      | 416      |
# |    critic_loss     | 3.49e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 52800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -451     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 66       |
# |    time_elapsed    | 806      |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | 435      |
# |    critic_loss     | 4.19e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 53800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -490     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 67       |
# |    time_elapsed    | 816      |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | 408      |
# |    critic_loss     | 4.18e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 54800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -476     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 67       |
# |    time_elapsed    | 826      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | 394      |
# |    critic_loss     | 3.69e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 55800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -477     |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 67       |
# |    time_elapsed    | 842      |
# |    total_timesteps | 57000    |
# | train/             |          |
# |    actor_loss      | 369      |
# |    critic_loss     | 3.42e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 56800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -405     |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 67       |
# |    time_elapsed    | 856      |
# |    total_timesteps | 58000    |
# | train/             |          |
# |    actor_loss      | 375      |
# |    critic_loss     | 3.7e+04  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 57800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -410     |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 67       |
# |    time_elapsed    | 871      |
# |    total_timesteps | 59000    |
# | train/             |          |
# |    actor_loss      | 354      |
# |    critic_loss     | 3.27e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 58800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -393     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 67       |
# |    time_elapsed    | 885      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | 325      |
# |    critic_loss     | 3e+04    |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 59800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -342     |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 67       |
# |    time_elapsed    | 900      |
# |    total_timesteps | 61000    |
# | train/             |          |
# |    actor_loss      | 314      |
# |    critic_loss     | 3.1e+04  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 60800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -260     |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 67       |
# |    time_elapsed    | 914      |
# |    total_timesteps | 62000    |
# | train/             |          |
# |    actor_loss      | 307      |
# |    critic_loss     | 2.48e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 61800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 68       |
# |    time_elapsed    | 924      |
# |    total_timesteps | 63000    |
# | train/             |          |
# |    actor_loss      | 287      |
# |    critic_loss     | 2.21e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 62800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 68       |
# |    time_elapsed    | 939      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | 267      |
# |    critic_loss     | 1.87e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 63800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 68       |
# |    time_elapsed    | 954      |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | 262      |
# |    critic_loss     | 2.53e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 64800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -37.5    |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 68       |
# |    time_elapsed    | 969      |
# |    total_timesteps | 66000    |
# | train/             |          |
# |    actor_loss      | 244      |
# |    critic_loss     | 2.13e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 65800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -7.75    |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 68       |
# |    time_elapsed    | 984      |
# |    total_timesteps | 67000    |
# | train/             |          |
# |    actor_loss      | 245      |
# |    critic_loss     | 1.86e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 66800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 28.7     |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 68       |
# |    time_elapsed    | 999      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | 235      |
# |    critic_loss     | 1.32e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 67800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.4     |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 67       |
# |    time_elapsed    | 1015     |
# |    total_timesteps | 69000    |
# | train/             |          |
# |    actor_loss      | 218      |
# |    critic_loss     | 1.67e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 68800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.7     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 67       |
# |    time_elapsed    | 1030     |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | 212      |
# |    critic_loss     | 1.42e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 69800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41       |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 67       |
# |    time_elapsed    | 1045     |
# |    total_timesteps | 71000    |
# | train/             |          |
# |    actor_loss      | 204      |
# |    critic_loss     | 1.45e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 70800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41       |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 67       |
# |    time_elapsed    | 1061     |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | 198      |
# |    critic_loss     | 1.21e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 71800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40.7     |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 67       |
# |    time_elapsed    | 1076     |
# |    total_timesteps | 73000    |
# | train/             |          |
# |    actor_loss      | 194      |
# |    critic_loss     | 1.29e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 72800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40.7     |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 67       |
# |    time_elapsed    | 1091     |
# |    total_timesteps | 74000    |
# | train/             |          |
# |    actor_loss      | 195      |
# |    critic_loss     | 1.03e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 73800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40.5     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 67       |
# |    time_elapsed    | 1104     |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | 188      |
# |    critic_loss     | 9.25e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 74800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.9     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 67       |
# |    time_elapsed    | 1119     |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | 167      |
# |    critic_loss     | 1.24e+04 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 75800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 67       |
# |    time_elapsed    | 1134     |
# |    total_timesteps | 77000    |
# | train/             |          |
# |    actor_loss      | 166      |
# |    critic_loss     | 7.99e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 76800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 67       |
# |    time_elapsed    | 1149     |
# |    total_timesteps | 78000    |
# | train/             |          |
# |    actor_loss      | 167      |
# |    critic_loss     | 9.86e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 77800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 38.9     |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 67       |
# |    time_elapsed    | 1163     |
# |    total_timesteps | 79000    |
# | train/             |          |
# |    actor_loss      | 166      |
# |    critic_loss     | 9.32e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 78800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 38.4     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 67       |
# |    time_elapsed    | 1178     |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | 161      |
# |    critic_loss     | 8.1e+03  |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 79800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 38.9     |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 67       |
# |    time_elapsed    | 1193     |
# |    total_timesteps | 81000    |
# | train/             |          |
# |    actor_loss      | 152      |
# |    critic_loss     | 9.16e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 80800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 38.9     |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 67       |
# |    time_elapsed    | 1209     |
# |    total_timesteps | 82000    |
# | train/             |          |
# |    actor_loss      | 153      |
# |    critic_loss     | 7.99e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 81800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.2     |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 67       |
# |    time_elapsed    | 1223     |
# |    total_timesteps | 83000    |
# | train/             |          |
# |    actor_loss      | 143      |
# |    critic_loss     | 8.73e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 82800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 67       |
# |    time_elapsed    | 1238     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | 151      |
# |    critic_loss     | 7.03e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 83800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.5     |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 67       |
# |    time_elapsed    | 1254     |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | 142      |
# |    critic_loss     | 6.62e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 84800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40.3     |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 67       |
# |    time_elapsed    | 1269     |
# |    total_timesteps | 86000    |
# | train/             |          |
# |    actor_loss      | 141      |
# |    critic_loss     | 5.99e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 85800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40       |
# | time/              |          |
# |    episodes        | 870      |
# |    fps             | 67       |
# |    time_elapsed    | 1285     |
# |    total_timesteps | 87000    |
# | train/             |          |
# |    actor_loss      | 145      |
# |    critic_loss     | 6.81e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 86800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 67       |
# |    time_elapsed    | 1300     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | 140      |
# |    critic_loss     | 5.63e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 87800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 40.6     |
# | time/              |          |
# |    episodes        | 890      |
# |    fps             | 67       |
# |    time_elapsed    | 1315     |
# |    total_timesteps | 89000    |
# | train/             |          |
# |    actor_loss      | 136      |
# |    critic_loss     | 5.55e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 88800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.4     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 67       |
# |    time_elapsed    | 1331     |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 4.93e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 89800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.6     |
# | time/              |          |
# |    episodes        | 910      |
# |    fps             | 67       |
# |    time_elapsed    | 1346     |
# |    total_timesteps | 91000    |
# | train/             |          |
# |    actor_loss      | 135      |
# |    critic_loss     | 5.47e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 90800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.8     |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 67       |
# |    time_elapsed    | 1361     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 5.94e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 91800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 41.9     |
# | time/              |          |
# |    episodes        | 930      |
# |    fps             | 67       |
# |    time_elapsed    | 1376     |
# |    total_timesteps | 93000    |
# | train/             |          |
# |    actor_loss      | 127      |
# |    critic_loss     | 6.14e+03 |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 92800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 42.8     |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 67       |
# |    time_elapsed    | 1391     |
# |    total_timesteps | 94000    |
# | train/             |          |
# |    actor_loss      | 126      |
# |    critic_loss     | 5.07e+03 |
# |    learning_rate   | 1e-06    |
# ...
# |    ep_rew_mean     | 81.6     |
# | time/              |          |
# |    episodes        | 49700    |
# |    fps             | 69       |
# |    time_elapsed    | 71909    |
# |    total_timesteps | 4970000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 25.1     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4969800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.3     |
# | time/              |          |
# |    episodes        | 49710    |
# |    fps             | 69       |
# |    time_elapsed    | 71925    |
# |    total_timesteps | 4971000  |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 31       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4970800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.1     |
# | time/              |          |
# |    episodes        | 49720    |
# |    fps             | 69       |
# |    time_elapsed    | 71940    |
# |    total_timesteps | 4972000  |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 24.1     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4971800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 80.9     |
# | time/              |          |
# |    episodes        | 49730    |
# |    fps             | 69       |
# |    time_elapsed    | 71954    |
# |    total_timesteps | 4973000  |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 24.7     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4972800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.2     |
# | time/              |          |
# |    episodes        | 49740    |
# |    fps             | 69       |
# |    time_elapsed    | 71969    |
# |    total_timesteps | 4974000  |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 23.8     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4973800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.6     |
# | time/              |          |
# |    episodes        | 49750    |
# |    fps             | 69       |
# |    time_elapsed    | 71983    |
# |    total_timesteps | 4975000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 31.6     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4974800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.1     |
# | time/              |          |
# |    episodes        | 49760    |
# |    fps             | 69       |
# |    time_elapsed    | 71997    |
# |    total_timesteps | 4976000  |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 23.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4975800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.8     |
# | time/              |          |
# |    episodes        | 49770    |
# |    fps             | 69       |
# |    time_elapsed    | 72011    |
# |    total_timesteps | 4977000  |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4976800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.4     |
# | time/              |          |
# |    episodes        | 49780    |
# |    fps             | 69       |
# |    time_elapsed    | 72026    |
# |    total_timesteps | 4978000  |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 32.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4977800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.1     |
# | time/              |          |
# |    episodes        | 49790    |
# |    fps             | 69       |
# |    time_elapsed    | 72040    |
# |    total_timesteps | 4979000  |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4978800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.6     |
# | time/              |          |
# |    episodes        | 49800    |
# |    fps             | 69       |
# |    time_elapsed    | 72054    |
# |    total_timesteps | 4980000  |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 26       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4979800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.7     |
# | time/              |          |
# |    episodes        | 49810    |
# |    fps             | 69       |
# |    time_elapsed    | 72068    |
# |    total_timesteps | 4981000  |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 28.2     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4980800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.1     |
# | time/              |          |
# |    episodes        | 49820    |
# |    fps             | 69       |
# |    time_elapsed    | 72082    |
# |    total_timesteps | 4982000  |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 28       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4981800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.1     |
# | time/              |          |
# |    episodes        | 49830    |
# |    fps             | 69       |
# |    time_elapsed    | 72097    |
# |    total_timesteps | 4983000  |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4982800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.7     |
# | time/              |          |
# |    episodes        | 49840    |
# |    fps             | 69       |
# |    time_elapsed    | 72111    |
# |    total_timesteps | 4984000  |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4983800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.5     |
# | time/              |          |
# |    episodes        | 49850    |
# |    fps             | 69       |
# |    time_elapsed    | 72126    |
# |    total_timesteps | 4985000  |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 25       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4984800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81       |
# | time/              |          |
# |    episodes        | 49860    |
# |    fps             | 69       |
# |    time_elapsed    | 72140    |
# |    total_timesteps | 4986000  |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4985800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.1     |
# | time/              |          |
# |    episodes        | 49870    |
# |    fps             | 69       |
# |    time_elapsed    | 72155    |
# |    total_timesteps | 4987000  |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4986800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.5     |
# | time/              |          |
# |    episodes        | 49880    |
# |    fps             | 69       |
# |    time_elapsed    | 72169    |
# |    total_timesteps | 4988000  |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 26.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4987800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.8     |
# | time/              |          |
# |    episodes        | 49890    |
# |    fps             | 69       |
# |    time_elapsed    | 72183    |
# |    total_timesteps | 4989000  |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 33       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4988800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.4     |
# | time/              |          |
# |    episodes        | 49900    |
# |    fps             | 69       |
# |    time_elapsed    | 72197    |
# |    total_timesteps | 4990000  |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 24.3     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4989800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82       |
# | time/              |          |
# |    episodes        | 49910    |
# |    fps             | 69       |
# |    time_elapsed    | 72213    |
# |    total_timesteps | 4991000  |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4990800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82       |
# | time/              |          |
# |    episodes        | 49920    |
# |    fps             | 69       |
# |    time_elapsed    | 72227    |
# |    total_timesteps | 4992000  |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 27.4     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4991800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 81.9     |
# | time/              |          |
# |    episodes        | 49930    |
# |    fps             | 69       |
# |    time_elapsed    | 72241    |
# |    total_timesteps | 4993000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 24       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4992800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.8     |
# | time/              |          |
# |    episodes        | 49940    |
# |    fps             | 69       |
# |    time_elapsed    | 72256    |
# |    total_timesteps | 4994000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4993800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 83       |
# | time/              |          |
# |    episodes        | 49950    |
# |    fps             | 69       |
# |    time_elapsed    | 72270    |
# |    total_timesteps | 4995000  |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4994800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 83.3     |
# | time/              |          |
# |    episodes        | 49960    |
# |    fps             | 69       |
# |    time_elapsed    | 72285    |
# |    total_timesteps | 4996000  |
# | train/             |          |
# |    actor_loss      | -31.4    |
# |    critic_loss     | 22       |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4995800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.6     |
# | time/              |          |
# |    episodes        | 49970    |
# |    fps             | 69       |
# |    time_elapsed    | 72299    |
# |    total_timesteps | 4997000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 28.1     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4996800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.5     |
# | time/              |          |
# |    episodes        | 49980    |
# |    fps             | 69       |
# |    time_elapsed    | 72315    |
# |    total_timesteps | 4998000  |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4997800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.3     |
# | time/              |          |
# |    episodes        | 49990    |
# |    fps             | 69       |
# |    time_elapsed    | 72331    |
# |    total_timesteps | 4999000  |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4998800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 82.1     |
# | time/              |          |
# |    episodes        | 50000    |
# |    fps             | 69       |
# |    time_elapsed    | 72347    |
# |    total_timesteps | 5000000  |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 4999800  |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
model = TD3.load("TD3_v1")

# obs = env.reset()
# while True:
#     action, _states = model.predict(obs)
#     obs, rewards, dones, info = env.step(action)
#     env.render()

for i in range(10):
    obs = env.reset()
    print(env.buf_infos)
    for j in range(100):
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        print(obs)
    print()
# Out:
# [{'Steps': 100, 'Current': array([365.8259], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [2, 10, 4, 10, 7, 10], 'episode': {'r': 73.838011, 'l': 100, 't': 91133.896559}, 'terminal_observation': array([   30.     , 10974.777  ,   226.98438], dtype=float32)}]
# [[  15.     5628.5757 5628.5757]]
# [[   30.     10977.15    5348.5747]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[   30.      10977.15      204.10938]]
# [[   45.      10773.041    -204.10938]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([365.90503], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [2, 10, 8, 10, 4, 10], 'episode': {'r': 57.787443, 'l': 100, 't': 91875.404501}, 'terminal_observation': array([   30.     , 10977.15   ,   204.10938], dtype=float32)}]
# [[  15.    5631.287 5631.287]]
# [[   30.     11253.6455  5622.3584]]
# [[   45.    16803.596  5549.95 ]]
# [[   60.    21797.756  4994.16 ]]
# [[   75.      22632.328     834.57227]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[   90.     16246.181  -6386.1475]]
# [[   75.     22632.328   6386.1475]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([180.51312], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [5, 10, 4, 10, 5, 10], 'episode': {'r': 81.913252, 'l': 100, 't': 91875.519115}, 'terminal_observation': array([   90.    , 16246.181 , -6386.1475], dtype=float32)}]
# [[  15.    5488.892 5488.892]]
# [[  30.     7052.5405 1563.6484]]
# [[  45.      7463.3267   410.78613]]
# [[  60.     9943.008  2479.6812]]
# [[   75.     12407.237   2464.2295]]
# [[   90.     14833.755   2426.5176]]
# [[  105.     17169.742   2335.9873]]
# [[  120.     19291.232   2121.4902]]
# [[  135.     20909.826   1618.5938]]
# [[  150.      21359.512     449.68555]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[  150.     21359.512    960.4961]]
# [[  165.     20399.016   -960.4961]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([142.39674], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [1, 10, 10, 10, 2, 10], 'episode': {'r': 94.078833, 'l': 100, 't': 91875.62939}, 'terminal_observation': array([  150.    , 21359.512 ,   960.4961], dtype=float32)}]
# [[  15.     5630.9424 5630.9424]]
# [[   30.    11239.073  5608.131]]
# [[   45.     16469.848   5230.7744]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[   60.      15740.545    -729.30273]]
# [[   45.      16469.848     729.30273]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([262.3424], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [5, 10, 3, 10, 7, 10], 'episode': {'r': 85.409206, 'l': 100, 't': 91875.739869}, 'terminal_observation': array([   60.     , 15740.545  ,  -729.30273], dtype=float32)}]
# [[  15.     5631.1865 5631.1865]]
# [[   30.    11247.233  5616.047]]
# [[   45.     16634.      5386.7666]]
# [[   60.     18513.854   1879.8535]]
# [[   75.     21703.756   3189.9023]]
# [[   90.     22583.836    880.0801]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[   90.     22583.836   8084.5674]]
# [[  105.     14499.269  -8084.5674]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([250.93152], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [6, 10, 5, 10, 3, 10], 'episode': {'r': 80.055528, 'l': 100, 't': 91875.848502}, 'terminal_observation': array([   90.    , 22583.836 ,  8084.5674], dtype=float32)}]
# [[  15.     5553.2666 5553.2666]]
# [[  30.    9009.104 3455.837]]
# [[   45.     13126.327   4117.2236]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[   60.     11288.823  -1837.5039]]
# [[   45.     13126.327   1837.5039]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([188.14705], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [5, 10, 3, 10, 1, 10], 'episode': {'r': 85.85669, 'l': 100, 't': 91875.957237}, 'terminal_observation': array([   60.    , 11288.823 , -1837.5039], dtype=float32)}]
# [[  15.    5631.499 5631.499]]
# [[   30.     11257.889   5626.3896]]
# [[   45.     16853.275   5595.3867]]
# [[   60.    22272.975  5419.699]]
# [[   75.     26737.246   4464.2715]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[   90.     26148.062   -589.1836]]
# [[   75.     26737.246    589.1836]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([290.53403], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [5, 10, 5, 10, 7, 10], 'episode': {'r': 93.778964, 'l': 100, 't': 91876.064862}, 'terminal_observation': array([   90.    , 26148.062 ,  -589.1836], dtype=float32)}]
# [[  15.     5490.3887 5490.3887]]
# [[  30.     7205.1636 1714.7749]]
# [[   45.     10789.196   3584.0327]]
# [[   60.     14281.721   3492.5244]]
# [[   75.    17290.473  3008.752]]
# [[   90.      17780.658     490.18555]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[   90.    17780.658  6776.043]]
# [[  105.    11004.615 -6776.043]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([197.56287], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [1, 10, 5, 10, 7, 10], 'episode': {'r': 78.298338, 'l': 100, 't': 91876.172801}, 'terminal_observation': array([   90.   , 17780.658,  6776.043], dtype=float32)}]
# [[  15.     5628.7583 5628.7583]]
# [[   30.     10992.311   5363.5522]]
# [[   45.      11094.003     101.69238]]
# [[   60.    14688.839  3594.836]]
# [[   75.     17794.248   3105.4092]]
# [[   90.     18320.12     525.8711]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[   90.     18320.12    6872.7188]]
# [[  105.     11447.4    -6872.7188]]
# [[0. 0. 0.]]
#
# [{'Steps': 100, 'Current': array([203.55688], dtype=float32), 'Temperature': 25.0, 'Irradiance': 1000.0, 'Shading': [5, 10, 2, 10, 9, 10], 'episode': {'r': 78.791986, 'l': 100, 't': 91876.27944}, 'terminal_observation': array([   90.    , 18320.12  ,  6872.7188], dtype=float32)}]
# [[  15.     5627.0664 5627.0664]]
# [[   30.    10837.156  5210.09 ]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[   30.     10837.156   3088.2764]]
# [[   45.      7748.88   -3088.2764]]
# [[0. 0. 0.]]
